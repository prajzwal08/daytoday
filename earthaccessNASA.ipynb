# %%
import earthaccess

# %%
auth = earthaccess.login(persist=True)

# %%
# Define date range
start_date = "2020-07-01"
end_date = "2020-07-08"

# Search for data from ECO2LSTE.002
results = earthaccess.search_data(
    short_name="ECO_L2G_LSTE",
    version="002",
    bounding_box=(11.04, 46.01, 11.05, 46.02),
    temporal=(start_date, end_date),
)

# print(f"Found {len(results)} granules")
# Out:
# Found 2 granules

# %%
results
# Out:
# [Collection: {'ShortName': 'ECO_L2G_LSTE', 'Version': '002'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': 5.6385, 'EastBoundingCoordinate': 11.928, 'NorthBoundingCoordinate': 49.9226, 'SouthBoundingCoordinate': 44.9729}]}}}
#  Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2020-07-08T04:40:56.808Z', 'EndingDateTime': '2020-07-08T04:41:48.777Z'}}
#  Size(MB): 242.85
#  Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2G_LSTE.002/ECOv002_L2G_LSTE_11370_012_20200708T044056_0712_01/ECOv002_L2G_LSTE_11370_012_20200708T044056_0712_01.h5'],
#  Collection: {'ShortName': 'ECO_L2G_LSTE', 'Version': '002'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': 9.8224, 'EastBoundingCoordinate': 16.1063, 'NorthBoundingCoordinate': 48.5212, 'SouthBoundingCoordinate': 43.4777}]}}}
#  Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2020-07-08T04:41:48.777Z', 'EndingDateTime': '2020-07-08T04:42:40.747Z'}}
#  Size(MB): 233.39
#  Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/ECO_L2G_LSTE.002/ECOv002_L2G_LSTE_11370_013_20200708T044148_0712_01/ECOv002_L2G_LSTE_11370_013_20200708T044148_0712_01.h5']]
